# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
import string
#https://stackoverflow.com/questions/19726663/how-to-save-the-pandas-dataframe-series-data-as-a-figure
import six
import math

# %%
tbpath = "../../results/tables/"
productpath = "../../results/"

# %%
df = pd.read_csv(tbpath + 'fit_table_reweighted.csv')

# %%
rois = df.roi.unique()

# %%
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 18}

matplotlib.rc('font', **font)

def simpleaxis(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    
f = plt.figure(figsize=(10,10))
for roi in ['Italy','Sweden','Denmark']:#rois:
    ifr = []
    r = []
    for wk in np.arange(11).astype(str):
        try:
            col = 'ifr (week '+wk+')'
            ifr.append(df.loc[(df.roi==roi)&(df['quantile']=='0.5'), col].values[0])
            if wk == '0':
                col = 'R0'
            else:
                col = 'Rt (week '+wk+')'
            r.append(df.loc[(df.roi==roi)&(df['quantile']=='0.5'), col].values[0])
        except:
            pass
    plt.plot(r,ifr)
